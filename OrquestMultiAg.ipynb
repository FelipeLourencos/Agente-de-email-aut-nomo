# %%
# %pip install langchain langchain-google-genai langchain_community tavily-python aiosqlite langchain-tavily 
# %pip install langgraph-checkpoint-sqlite 
# %pip install langgraph langgraph-checkpoint-sqlite
# %pip install langgraph

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated, List
import operator
from langgraph.checkpoint.sqlite import SqliteSaver
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage, ChatMessage

import sqlite3 
from langgraph.checkpoint.sqlite import SqliteSaver 
conn = sqlite3.connect("checkpoints.db", check_same_thread=False) 
memory = SqliteSaver(conn)

# %%
import google.genai as genai
import os
from dotenv import load_dotenv

load_dotenv()

os.environ['GOOGLE_API_KEY'] = os.getenv('GEMINI_API_KEY') 
os.environ['TAVILY_API_KEY'] = os.getenv('TAVILY_API_KEY')

# %%
from typing import TypedDict, List

class AgentState(TypedDict):
    task: str
    plan: str
    draft: str
    critique: str
    content: List[str]
    revision_number: int
    max_revisions: int

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
PLAN_PROMPT = """Você é um escritor especialista com a tarefa de criar um esboço de alto nível para uma redação. \
Escreva esse esboço para o tópico fornecido pelo usuário. Apresente um plano da redação junto com quaisquer notas \
ou instruções relevantes para as seções."""

# %%
WRITER_PROMPT = """Você é um assistente de redação com a tarefa de escrever excelentes redações de 5 parágrafos. \
Gere a melhor redação possível para a solicitação do usuário e o esboço inicial. \
Se o usuário fornecer críticas, responda com uma versão revisada das suas tentativas anteriores. \
Utilize todas as informações abaixo conforme necessário:

------

{content}"""

# %%
REFLECTION_PROMPT = """Você é um professor corrigindo uma redação submetida. \
Gere uma crítica e recomendações para a submissão do usuário. \
Forneça recomendações detalhadas, incluindo pedidos sobre extensão, profundidade, estilo, etc."""

# %%
RESEARCH_PLAN_PROMPT = """Você é um pesquisador encarregado de fornecer informações que podem \
ser usadas ao escrever a seguinte redação. Gere uma lista de consultas de pesquisa que \
recolham quaisquer informações relevantes. Gere no máximo 3 consultas."""

# %%
RESEARCH_CRITIQUE_PROMPT = """Você é um pesquisador encarregado de fornecer informações que podem \
ser usadas ao fazer quaisquer revisões solicitadas (conforme descrito abaixo). \
Gere uma lista de consultas de pesquisa que recolham quaisquer informações relevantes. Gere no máximo 3 consultas."""

# %%
from pydantic import BaseModel
from typing import List

class Queries(BaseModel):
    queries: List[str]

# %%
from tavily import TavilyClient
import os
tavily = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

# %%
def plan_node(state: AgentState):
    messages = [
        SystemMessage(content=PLAN_PROMPT), 
        HumanMessage(content=state['task'])
    ]
    response = model.invoke(messages)
    return {"plan": response.content}

# %%
def research_plan_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_PLAN_PROMPT),
        HumanMessage(content=state['task'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def generation_node(state: AgentState):
    content = "\n\n".join(state['content'] or [])
    user_message = HumanMessage(
        content=f"{state['task']}\n\nHere is my plan:\n\n{state['plan']}")
    messages = [
        SystemMessage(
            content=WRITER_PROMPT.format(content=content)
        ),
        user_message
        ]
    response = model.invoke(messages)
    return {
        "draft": response.content, 
        "revision_number": state.get("revision_number", 1) + 1
    }

# %%
def reflection_node(state: AgentState):
    messages = [
        SystemMessage(content=REFLECTION_PROMPT), 
        HumanMessage(content=state['draft'])
    ]
    response = model.invoke(messages)
    return {"critique": response.content}

# %%
def research_critique_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_CRITIQUE_PROMPT),
        HumanMessage(content=state['critique'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def should_continue(state):
    if state["revision_number"] > state["max_revisions"]:
        return END
    return "reflect"

# %%
builder = StateGraph(AgentState)

# %%
builder.add_node("planner", plan_node)
builder.add_node("generate", generation_node)
builder.add_node("reflect", reflection_node)
builder.add_node("research_plan", research_plan_node)
builder.add_node("research_critique", research_critique_node)

# %%
builder.set_entry_point("planner")

# %%
builder.add_conditional_edges(
    "generate", 
    should_continue, 
    {END: END, "reflect": "reflect"}
)

# %%
builder.add_edge("planner", "research_plan")
builder.add_edge("research_plan", "generate")

builder.add_edge("reflect", "research_critique")
builder.add_edge("research_critique", "generate")

# %%
graph = builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display, Markdown
import os

print("\n--- Tentando Gerar PNG do Grafo via Mermaid (Requer Playwright!) ---")
try:

    image_data = graph.get_graph().draw_mermaid_png()
    display(Image(data=image_data))
    print("Grafo PNG gerado e exibido com sucesso!")

except Exception as e:

    print(f"\nErro ao tentar gerar o PNG do grafo: {e}")
    print("Isso pode ocorrer por:")
    print("1. O método `.draw_mermaid_png()` não existe na sua versão do LangGraph.")
    print("2. Faltam dependências como 'playwright' ou seus drivers não foram instalados.")
    print("   Tente: pip install playwright && playwright install")
    print("3. Outro erro inesperado ao acessar o grafo ou renderizar.")

    print("\n--- Tentando gerar apenas o código Mermaid (Fallback) ---")
    try:

        mermaid_code = graph.get_graph().draw_mermaid()
        print("\n--- Código Mermaid Gerado (Cole em https://mermaid.live/ ou use Markdown no notebook) ---")
        print(mermaid_code)

    except Exception as e_mermaid:
        print(f"Erro ao gerar código Mermaid: {e_mermaid}")
        print("Verifique se 'graph.get_graph()' está correto e acessível.")
# Out:
# --- Tentando Gerar PNG do Grafo via Mermaid (Requer Playwright!) ---
# Grafo PNG gerado e exibido com sucesso!

# %%
thread = {"configurable": {"thread_id": "1"}}
for s in graph.stream({
    'task': "Qual é a diferença entre o langchain e langsmith",
    "max_revisions": 2,
    "revision_number": 1,
    "content": [], 
}, thread):
    print(s)
# Out:
# {'planner': {'plan': 'Excelente tópico! LangChain e LangSmith são ferramentas cruciais no ecossistema de desenvolvimento de aplicações com Large Language Models (LLMs), mas servem a propósitos distintos e complementares.\n\nAqui está um esboço de alto nível para uma redação que explora a diferença entre eles, com notas e instruções para cada seção:\n\n---\n\n## Esboço da Redação: LangChain vs. LangSmith – Construindo vs. Observando Aplicações LLM\n\n**Título Provisório:** LangChain vs. LangSmith: Desvendando as Ferramentas Essenciais para o Desenvolvimento e Observabilidade de Aplicações LLM\n\n**Objetivo da Redação:** Explicar claramente a função, propósito e as principais diferenças entre LangChain e LangSmith, destacando como eles se complementam no ciclo de vida de desenvolvimento de aplicações baseadas em LLMs.\n\n---\n\n### I. Introdução\n\n*   **Gancho:** O rápido avanço dos Large Language Models (LLMs) abriu um novo mundo de possibilidades para o desenvolvimento de aplicações inteligentes, mas também introduziu complexidades significativas.\n*   **Contexto:** Para construir e gerenciar essas aplicações de forma eficaz, os desenvolvedores recorrem a ferramentas especializadas. Duas das mais proeminentes são LangChain e LangSmith.\n*   **Apresentação das Ferramentas:** Breve menção de que LangChain é um framework para *construir* e LangSmith é uma plataforma para *observar e refinar*.\n*   **Tese:** Embora frequentemente associados, LangChain e LangSmith servem a propósitos distintos, porém altamente complementares: LangChain foca na orquestração e desenvolvimento de componentes de LLM, enquanto LangSmith se dedica à observabilidade, depuração e avaliação dessas aplicações.\n\n### II. LangChain: A Ferramenta de Orquestração e Construção\n\n*   **O que é:**\n    *   Um framework de código aberto (Python e JavaScript/TypeScript) projetado para simplificar a criação de aplicações baseadas em LLMs.\n    *   Não é um LLM em si, mas uma "cola" para conectar LLMs a outras fontes de dados e agentes.\n*   **Propósito Principal:**\n    *   Facilitar o desenvolvimento de aplicações complexas que vão além de uma única chamada a um LLM.\n    *   Permitir a criação de "cadeias" (chains) de operações, agentes e interações com dados externos.\n*   **Componentes Chave (com exemplos breves):**\n    *   **Modelos:** Abstrações para interagir com diferentes LLMs (OpenAI, Hugging Face, etc.).\n    *   **Prompts:** Gerenciamento e otimização de prompts (PromptTemplates).\n    *   **Chains:** Sequências de chamadas a LLMs e outras ferramentas (LLMChain, SequentialChain, RetrievalQAChain).\n    *   **Agentes:** Sistemas que usam LLMs para raciocinar e decidir quais ferramentas usar para atingir um objetivo (Search, Calculator, API calls).\n    *   **Retrievers:** Mecanismos para buscar informações de fontes externas (vetor stores, bancos de dados) para enriquecer o contexto do LLM (RAG - Retrieval Augmented Generation).\n    *   **Memória:** Capacidade de um LLM lembrar interações anteriores em uma conversa.\n*   **Foco:** Desenvolvimento, prototipagem, abstração da complexidade subjacente dos LLMs.\n*   **Analogia:** Pense em LangChain como um "kit de ferramentas" ou "planta de construção" para montar sua aplicação LLM.\n\n### III. LangSmith: A Plataforma de Observabilidade e Avaliação\n\n*   **O que é:**\n    *   Uma plataforma SaaS (Software as a Service) desenvolvida pela equipe do LangChain.\n    *   Projetada para ajudar os desenvolvedores a depurar, testar, avaliar e monitorar suas aplicações LLM.\n*   **Propósito Principal:**\n    *   Garantir a confiabilidade, desempenho e qualidade das aplicações LLM, desde o desenvolvimento até a produção.\n    *   Fornecer visibilidade sobre o comportamento interno das cadeias e agentes.\n*   **Funcionalidades Chave:**\n    *   **Tracing (Rastreamento):** Visualização detalhada de cada etapa de uma execução de cadeia ou agente (entradas, saídas, latência, tokens, erros). Essencial para entender o "p ...
# {'research_plan': {'content': ['# O que é LangChain? O LangChain é um framework de orquestração de código aberto para o desenvolvimento de aplicações com grandes modelos de linguagem (LLMs). Disponível em bibliotecas Python e Java, as ferramentas e APIs do LangChain simplificam o processo de criação de aplicações baseados em LLMs, como chatbots e agentes de IA. O LangChain atua como uma interface genérica para praticamente qualquer LLM, proporcionando um ambiente de desenvolvimento centralizado para construir aplicações LLM e integrá-los a fontes de dados externas e fluxos de trabalho de software. O LangChain pode facilitar a maioria dos casos de uso de LLMs e de processamento de linguagem natural (NLP), como chatbots, pesquisa inteligente, respostas a perguntas, serviços desumarização ou até mesmo agentes\xa0de IA capazes de automação robótica de processos. ### Integrações com LLMs. LLMs não são aplicações independentes: são modelos estatísticos previamente treinados que devem ser combinados com uma aplicação (e em alguns casos com fontes de dados específicas) para atenderem à sua finalidade.', 'Home / Blog / O que é o LangChain e como funciona. # O que é o LangChain e como funciona. * O que é o LangChain e sua importncia em aplicações com LLMs. * Vantagens de usar LangChain para desenvolver aplicações com LLMs. ## O que é o LangChain e sua importncia em aplicações com LLMs. O **LangChain** é uma **biblioteca em Python** projetada para facilitar a criação de aplicações que utilizam **modelos de linguagem de grande porte (LLMs)**, como o GPT-4, o DeepSeek ou o Grok. Sua importncia reside na capacidade de **integrar e orquestrar diferentes componentes** necessários para desenvolver funcionalidades avançadas, como **chatbots inteligentes**, sistemas de **perguntas e respostas (Q&A)** e ferramentas de **sumarização de texto**. Ao simplificar o processo de desenvolvimento com LLMs, o **LangChain** permite que desenvolvedores se concentrem na **lógica de negócio** e na **experiência do usuário**, eliminando a complexidade de lidar diretamente com as APIs dos modelos de linguagem.', '# O que é o LangSmith? Um dos maiores desafios na criação de aplicações de grandes modelos de linguagem (LLM) é entender por que um sistema de inteligência artificial (IA) falha ou se comporta de forma inesperada, uma vez implementar. Os desenvolvedores frequentemente têm dificuldades para rastrear erros, ajuste fino de prompts, avaliar desempenho em edge casos ou depurar uso de ferramentas e problemas de memória em workflows complexos de agentes. Ele permite que os desenvolvedores inspecionem rastreamentos, monitorem o desempenho, testem diferentes versões de prompt e rastreiem como as ferramentas externas e a memória são usadas em tempo real, tudo isso em uma interface unificada projetada para tornar os aplicativos LLM mais robustos e prontos para produção. LangChain e LangSmith são ferramentas para apoiar o desenvolvimento de LLM, mas o propósito de cada ferramenta varia. Enquanto o LangChain ajuda a criar workflows, o LangSmith ajuda a garantir que eles funcionem sem problemas, oferecendo ferramentas para depuração, monitoramento e gerenciamento de sistemas complexos de AI.', '# Marketing – O que é e para que serve? Marketing – O que é e para que serve. Marketing – O que é e para que serve. Todos nós já ouvimos falar de marketing mais do que uma vez ao longo da nossa vida, no entanto muitas pessoas ainda não sabem muito bem o que é, e para que serve. De acordo com Philip Kotler (o guru de marketing) “Marketing é um processo social e gerencial pelo qual indivíduos e grupos obtêm o que necessitam e desejam por meio da criação e troca de produtos e valores. Quando se procede à criação de um novo produto é necessário ter em conta o aspeto exterior, características técnicas, a embalagem, a marca e as opções possíveis para que o produto seja atrativo para o cliente. A promoção é um conjunto de ações que a empresa desenvolve com o intuito de dar a conhecer ...
# {'generate': {'draft': 'Excelente tópico! LangChain e LangSmith são ferramentas cruciais no ecossistema de desenvolvimento de aplicações com Large Language Models (LLMs), mas servem a propósitos distintos e complementares.\n\nAqui está a redação baseada no seu esboço:\n\n---\n\n## LangChain vs. LangSmith: Desvendando as Ferramentas Essenciais para o Desenvolvimento e Observabilidade de Aplicações LLM\n\nO rápido avanço dos Large Language Models (LLMs) abriu um novo mundo de possibilidades para o desenvolvimento de aplicações inteligentes, mas também introduziu complexidades significativas. Para construir e gerenciar essas aplicações de forma eficaz, os desenvolvedores recorrem a ferramentas especializadas. Duas das mais proeminentes são LangChain e LangSmith. Enquanto o LangChain é um framework de orquestração de código aberto para *construir* aplicações com LLMs, o LangSmith é uma plataforma para *observar, depurar e refinar* o comportamento dessas aplicações. Embora frequentemente associados, LangChain e LangSmith servem a propósitos distintos, porém altamente complementares: LangChain foca na orquestração e desenvolvimento de componentes de LLM, enquanto LangSmith se dedica à observabilidade, depuração e avaliação dessas aplicações.\n\nO LangChain atua como a espinha dorsal para a construção de aplicações LLM. É um framework de orquestração de código aberto, disponível em bibliotecas Python e Java, projetado para simplificar a criação de soluções baseadas em LLMs como GPT-4 ou DeepSeek. Sua importância reside na capacidade de integrar e orquestrar diferentes componentes, permitindo que os desenvolvedores criem funcionalidades avançadas como chatbots inteligentes, sistemas de perguntas e respostas (Q&A), ferramentas de sumarização de texto e até mesmo agentes de IA capazes de automação robótica de processos. O LangChain não é um LLM em si, mas uma "cola" que conecta LLMs a fontes de dados externas e fluxos de trabalho de software, abstraindo a complexidade das APIs dos modelos e permitindo que os desenvolvedores se concentrem na lógica de negócio e na experiência do usuário. Pense no LangChain como um "kit de ferramentas" ou "planta de construção" para montar sua aplicação LLM.\n\nPor outro lado, o LangSmith é a plataforma essencial para garantir que as aplicações LLM funcionem conforme o esperado. Desenvolvido pela equipe do LangChain, o LangSmith é uma plataforma SaaS projetada para ajudar os desenvolvedores a depurar, testar, avaliar e monitorar suas aplicações LLM. Um dos maiores desafios na criação de aplicações LLM é entender por que um sistema de IA falha ou se comporta de forma inesperada. O LangSmith resolve isso permitindo que os desenvolvedores inspecionem rastreamentos (tracing), monitorem o desempenho, testem diferentes versões de prompt e rastreiem como as ferramentas externas e a memória são usadas em tempo real, tudo isso em uma interface unificada. Ele é crucial para identificar e resolver problemas em prompts, chamadas de ferramentas e lógica da cadeia, garantindo a confiabilidade, desempenho e qualidade das aplicações desde o desenvolvimento até a produção. O LangSmith pode ser visto como o "painel de controle", "inspetor de qualidade" e "monitor de desempenho" da sua aplicação LLM.\n\nAs diferenças entre LangChain e LangSmith são claras em sua natureza e propósito. O LangChain é um framework/biblioteca de código aberto focado em construir e orquestrar a lógica da aplicação, atuando principalmente nas fases de desenvolvimento e prototipagem. Sua saída principal é o código funcional e os componentes da aplicação LLM. Em contraste, o LangSmith é uma plataforma/serviço (SaaS) com foco em observar, depurar, testar, avaliar e monitorar a aplicação, sendo mais relevante nas fases de teste, pré-produção e produção. Sua saída principal são insights, dados de desempenho, rastreamentos visuais e resultados de avaliação. Embora o LangChain possa ser usado independentemente, o LangSmith é mais útil com uma aplicação L ...
# {'reflect': {'critique': 'Olá! Que excelente escolha de tópico e que redação bem estruturada você apresentou. Como seu professor, posso dizer que você capturou a essência e as distinções cruciais entre LangChain e LangSmith de forma muito clara e didática. Seu texto é informativo, bem organizado e utiliza analogias eficazes para explicar conceitos complexos.\n\nVamos a uma análise mais detalhada e algumas recomendações para elevar ainda mais a qualidade da sua redação.\n\n---\n\n### **Avaliação Geral**\n\n**Pontos Fortes:**\n\n1.  **Clareza e Didatismo:** Você explica conceitos complexos de forma acessível, o que é fundamental para um tópico técnico. A distinção entre "construir" (LangChain) e "observar/depurar" (LangSmith) é estabelecida logo no início e mantida consistentemente.\n2.  **Estrutura Lógica:** A redação segue um fluxo muito lógico: introdução, detalhamento de cada ferramenta, comparação direta, sinergia e conclusão. Isso facilita a compreensão do leitor.\n3.  **Analogias Eficazes:** As analogias ("cola", "kit de ferramentas/planta de construção" para LangChain; "painel de controle/inspetor de qualidade/monitor de desempenho" para LangSmith; "engenheiro/mecânico/testador" para a sinergia) são brilhantes e ajudam a solidificar o entendimento.\n4.  **Conteúdo Preciso:** As informações técnicas sobre ambas as ferramentas estão corretas e são relevantes. Você aborda os principais recursos e propósitos de cada uma.\n5.  **Linguagem Profissional:** O tom é acadêmico e profissional, adequado para o tema.\n\n**Áreas para Aprimoramento e Recomendações Detalhadas:**\n\nSua redação já está em um nível muito bom, mas podemos lapidá-la para torná-la ainda mais impactante e aprofundada.\n\n#### **1. Conteúdo e Profundidade**\n\n*   **Recomendação:** Embora você descreva bem o que cada ferramenta faz, poderia explorar um pouco mais o "como" em um nível ligeiramente mais técnico, sem perder a didática.\n    *   **Para LangChain:**\n        *   **Pedido:** No parágrafo sobre LangChain, você poderia mencionar brevemente seus componentes principais (Chains, Agents, Prompts, Retrievers, Memory) para ilustrar a modularidade e a flexibilidade do framework. Isso mostraria *como* ele orquestra, não apenas que ele orquestra.\n        *   **Exemplo:** "Sua arquitetura modular, baseada em componentes como *Chains* (sequências de chamadas a LLMs ou outras ferramentas), *Agents* (LLMs que decidem quais ferramentas usar), *Prompts* (modelos para interagir com LLMs), *Retrievers* (para buscar informações de fontes externas) e *Memory* (para manter o contexto conversacional), permite aos desenvolvedores montar soluções complexas de forma eficiente."\n    *   **Para LangSmith:**\n        *   **Pedido:** No parágrafo sobre LangSmith, você poderia dar um exemplo *muito breve* e concreto de um problema que ele ajuda a resolver. Por exemplo, como um "trace" visualiza uma falha específica.\n        *   **Exemplo:** "Ele é crucial para identificar e resolver problemas em prompts (e.g., \'por que meu LLM está alucinando neste ponto?\'), chamadas de ferramentas (e.g., \'a ferramenta externa foi chamada com os parâmetros corretos?\') e lógica da cadeia, permitindo aos desenvolvedores inspecionar cada etapa da execução em um \'trace\' visual detalhado."\n        *   **Pedido:** Enfatize um pouco mais a capacidade de *avaliação* do LangSmith. Você menciona "testar e avaliar" na sinergia, mas poderia reforçar isso no parágrafo dedicado a ele. LangSmith não é apenas para depuração, mas para garantir a qualidade e a performance através de testes e métricas.\n        *   **Exemplo:** "Além da depuração, o LangSmith é uma plataforma robusta para *avaliação sistemática*, permitindo que os desenvolvedores comparem o desempenho de diferentes prompts, modelos ou cadeias através de conjuntos de dados de teste, gerando métricas quantitativas para guiar as otimizações."\n\n#### **2. Estrutura e Fluxo**\n\n*   **Recomendação:** A repetição da ideia central de que são "d ...
# {'research_critique': {'content': ['# O que é LangChain? O LangChain é um framework de orquestração de código aberto para o desenvolvimento de aplicações com grandes modelos de linguagem (LLMs). Disponível em bibliotecas Python e Java, as ferramentas e APIs do LangChain simplificam o processo de criação de aplicações baseados em LLMs, como chatbots e agentes de IA. O LangChain atua como uma interface genérica para praticamente qualquer LLM, proporcionando um ambiente de desenvolvimento centralizado para construir aplicações LLM e integrá-los a fontes de dados externas e fluxos de trabalho de software. O LangChain pode facilitar a maioria dos casos de uso de LLMs e de processamento de linguagem natural (NLP), como chatbots, pesquisa inteligente, respostas a perguntas, serviços desumarização ou até mesmo agentes\xa0de IA capazes de automação robótica de processos. ### Integrações com LLMs. LLMs não são aplicações independentes: são modelos estatísticos previamente treinados que devem ser combinados com uma aplicação (e em alguns casos com fontes de dados específicas) para atenderem à sua finalidade.', 'Home / Blog / O que é o LangChain e como funciona. # O que é o LangChain e como funciona. * O que é o LangChain e sua importncia em aplicações com LLMs. * Vantagens de usar LangChain para desenvolver aplicações com LLMs. ## O que é o LangChain e sua importncia em aplicações com LLMs. O **LangChain** é uma **biblioteca em Python** projetada para facilitar a criação de aplicações que utilizam **modelos de linguagem de grande porte (LLMs)**, como o GPT-4, o DeepSeek ou o Grok. Sua importncia reside na capacidade de **integrar e orquestrar diferentes componentes** necessários para desenvolver funcionalidades avançadas, como **chatbots inteligentes**, sistemas de **perguntas e respostas (Q&A)** e ferramentas de **sumarização de texto**. Ao simplificar o processo de desenvolvimento com LLMs, o **LangChain** permite que desenvolvedores se concentrem na **lógica de negócio** e na **experiência do usuário**, eliminando a complexidade de lidar diretamente com as APIs dos modelos de linguagem.', '# O que é o LangSmith? Um dos maiores desafios na criação de aplicações de grandes modelos de linguagem (LLM) é entender por que um sistema de inteligência artificial (IA) falha ou se comporta de forma inesperada, uma vez implementar. Os desenvolvedores frequentemente têm dificuldades para rastrear erros, ajuste fino de prompts, avaliar desempenho em edge casos ou depurar uso de ferramentas e problemas de memória em workflows complexos de agentes. Ele permite que os desenvolvedores inspecionem rastreamentos, monitorem o desempenho, testem diferentes versões de prompt e rastreiem como as ferramentas externas e a memória são usadas em tempo real, tudo isso em uma interface unificada projetada para tornar os aplicativos LLM mais robustos e prontos para produção. LangChain e LangSmith são ferramentas para apoiar o desenvolvimento de LLM, mas o propósito de cada ferramenta varia. Enquanto o LangChain ajuda a criar workflows, o LangSmith ajuda a garantir que eles funcionem sem problemas, oferecendo ferramentas para depuração, monitoramento e gerenciamento de sistemas complexos de AI.', '# Marketing – O que é e para que serve? Marketing – O que é e para que serve. Marketing – O que é e para que serve. Todos nós já ouvimos falar de marketing mais do que uma vez ao longo da nossa vida, no entanto muitas pessoas ainda não sabem muito bem o que é, e para que serve. De acordo com Philip Kotler (o guru de marketing) “Marketing é um processo social e gerencial pelo qual indivíduos e grupos obtêm o que necessitam e desejam por meio da criação e troca de produtos e valores. Quando se procede à criação de um novo produto é necessário ter em conta o aspeto exterior, características técnicas, a embalagem, a marca e as opções possíveis para que o produto seja atrativo para o cliente. A promoção é um conjunto de ações que a empresa desenvolve com o intuito de dar a conh ...
# {'generate': {'draft': '## LangChain vs. LangSmith: Desvendando as Ferramentas Essenciais para o Desenvolvimento e Observabilidade de Aplicações LLM\n\nO rápido avanço dos Large Language Models (LLMs) abriu um novo mundo de possibilidades para o desenvolvimento de aplicações inteligentes, mas também introduziu complexidades significativas. Para construir e gerenciar essas aplicações de forma eficaz, os desenvolvedores recorrem a ferramentas especializadas. Duas das mais proeminentes são LangChain e LangSmith. Embora frequentemente associados, LangChain e LangSmith servem a propósitos distintos, porém altamente complementares: LangChain foca na orquestração e desenvolvimento de componentes de LLM, enquanto LangSmith se dedica à observabilidade, depuração e avaliação dessas aplicações.\n\nLangChain é um framework de orquestração de código aberto, disponível em Python e JavaScript/TypeScript, projetado para simplificar a criação de aplicações baseadas em LLMs. Ele não é um LLM em si, mas atua como uma "cola" para conectar modelos de linguagem a outras fontes de dados e agentes, facilitando o desenvolvimento de funcionalidades avançadas como chatbots inteligentes, sistemas de perguntas e respostas (Q&A) e ferramentas de sumarização de texto. Seus componentes chave incluem abstrações para interagir com diferentes **Modelos** de LLM, gerenciamento de **Prompts**, **Chains** para sequenciar operações, **Agentes** que usam LLMs para raciocinar e decidir quais ferramentas usar, **Retrievers** para buscar informações externas e **Memória** para manter o contexto da conversa. Em essência, LangChain é o "kit de ferramentas" ou a "planta de construção" para montar sua aplicação LLM, permitindo que os desenvolvedores se concentrem na lógica de negócio e na experiência do usuário.\n\nPor outro lado, LangSmith é uma plataforma SaaS (Software as a Service) desenvolvida pela equipe do LangChain, projetada para ajudar os desenvolvedores a depurar, testar, avaliar e monitorar suas aplicações LLM. Seu propósito principal é garantir a confiabilidade, desempenho e qualidade das aplicações, desde o desenvolvimento até a produção, fornecendo visibilidade sobre o comportamento interno das cadeias e agentes. As funcionalidades chave do LangSmith incluem **Tracing** para visualizar detalhadamente cada etapa de uma execução, **Debugging** para identificar e resolver problemas, **Testing** com conjuntos de dados para comparar versões de prompts ou cadeias, **Evaluation** para medir a qualidade das respostas do LLM e **Monitoring** para acompanhar o desempenho em produção. LangSmith atua como o "painel de controle", "inspetor de qualidade" e "monitor de desempenho" da sua aplicação LLM.\n\nAs diferenças entre LangChain e LangSmith são claras: LangChain é um framework/biblioteca de código aberto para *construir* a lógica da aplicação, enquanto LangSmith é uma plataforma/serviço para *observar, depurar e otimizar* essa aplicação. LangChain foca no desenvolvimento e prototipagem, gerando código funcional e componentes de aplicação. LangSmith, por sua vez, é crucial nas fases de teste, depuração, pré-produção e produção, fornecendo insights, dados de desempenho e resultados de avaliação. Embora LangChain possa ser usado independentemente, LangSmith é mais eficaz com uma aplicação LLM já construída. A sinergia entre eles é poderosa: LangChain é o engenheiro que projeta e constrói o carro, e LangSmith é o mecânico e o testador que garante que o carro funcione perfeitamente, identifica problemas e otimiza seu desempenho através de um ciclo contínuo de feedback.\n\nEm suma, LangChain e LangSmith são ferramentas distintas, mas essenciais e complementares no desenvolvimento de aplicações LLM. LangChain capacita os desenvolvedores a construir e orquestrar componentes complexos de LLM, enquanto LangSmith oferece a visibilidade e as ferramentas necessárias para depurar, testar e monitorar essas aplicações em todas as fases do ciclo de vida. A combinação de ambos acelera ...
